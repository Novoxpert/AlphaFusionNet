# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/OHLCV/
# %cd Time-Series-Library
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/OHLCV
# /content/drive/MyDrive/OHLCV/Time-Series-Library
# btc_1min_embeddings.pkl       requirements.txt
# checkpoints		      result_long_term_forecast.txt
# CONTRIBUTING.md		      results
# data_provider		      run.py
# dataset			      scripts
# Embedding_extractor.ipynb     test_btc_embeddings.pkl
# embedding_to_csv_mapping.npy  test_embed_ohlcv.csv
# exp			      test_results
# fixed_data_btc_1min1.csv      timesnet_embeddings_768.npy
# fixed_data_btc_1min2.csv      timesnet_embeddings.pkl
# layers			      tsl
# LICENSE			      TSLib
# models			      tutorial
# pic			      utils
# README.md

# %%
# !git clone https://github.com/thuml/Time-Series-Library.git
# Out:
# Cloning into 'Time-Series-Library'...
# remote: Enumerating objects: 2039, done.
# remote: Counting objects: 100% (1223/1223), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 2039 (delta 1092), reused 1074 (delta 1073), pack-reused 816 (from 2)
# Receiving objects: 100% (2039/2039), 78.28 MiB | 16.47 MiB/s, done.
# Resolving deltas: 100% (1415/1415), done.
# Updating files: 100% (342/342), done.

# %%
# !pip install numpy==1.24.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 119.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.3 which is incompatible.
# blosc2 3.3.4 requires numpy>=1.26, but you have numpy 1.24.3 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,245 kB]
# ...

# %%
# !apt-get install -y unrar p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 95 not upgraded.

# %%
# !pip install patoolib
# Out:
# ERROR: Could not find a version that satisfies the requirement patoolib (from versions: none)
# ERROR: No matching distribution found for patoolib

# %%
# !pip install sktime
# !pip install reformer_pytorch

# %%
with open('data_provider/data_loader.py', 'r') as f:
    content = f.read()

# %%
# !ls -la ./dataset/

# %%
# !mkdir -p ./dataset/ETT-small/

# Download ETT datasets
# !wget -O ./dataset/ETT-small/ETTh1.csv https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
# !wget -O ./dataset/ETT-small/ETTh2.csv https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv
# !wget -O ./dataset/ETT-small/ETTm1.csv https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm1.csv
# !wget -O ./dataset/ETT-small/ETTm2.csv https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv

print("Downloaded ETT datasets!")
# Out:
# --2025-05-26 06:51:41--  https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2589657 (2.5M) [text/plain]
# Saving to: ‘./dataset/ETT-small/ETTh1.csv’
#
# ./dataset/ETT-small 100%[===================>]   2.47M  --.-KB/s    in 0.05s
#
# 2025-05-26 06:51:41 (46.0 MB/s) - ‘./dataset/ETT-small/ETTh1.csv’ saved [2589657/2589657]
#
# --2025-05-26 06:51:41--  https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
# !ls -la ./dataset/ETT-small/
# !head -5 ./dataset/ETT-small/ETTh1.csv
# Out:
# total 24459
# -rw------- 1 root root  2589657 May 26 06:51 ETTh1.csv
# -rw------- 1 root root  2417960 May 26 06:51 ETTh2.csv
# -rw------- 1 root root 10360719 May 26 06:51 ETTm1.csv
# -rw------- 1 root root  9677236 May 26 06:51 ETTm2.csv
# date,HUFL,HULL,MUFL,MULL,LUFL,LULL,OT
# 2016-07-01 00:00:00,5.827000141143799,2.009000062942505,1.5989999771118164,0.4620000123977661,4.203000068664552,1.3400000333786009,30.5310001373291
# 2016-07-01 01:00:00,5.692999839782715,2.075999975204468,1.4919999837875366,0.4259999990463257,4.142000198364259,1.371000051498413,27.78700065612793
# 2016-07-01 02:00:00,5.1570000648498535,1.741000056266785,1.2790000438690186,0.35499998927116394,3.776999950408936,1.218000054359436,27.78700065612793
# 2016-07-01 03:00:00,5.0900001525878915,1.9420000314712524,1.2790000438690186,0.3910000026226044,3.806999921798706,1.2790000438690186,25.04400062561035

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_96_24_TimesNet \
  --model TimesNet \
  --data ETTh1 \
  --features M \
  --seq_len 96 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 32 \
  --d_ff 32 \
  --top_k 5 \
  --des 'Exp' \
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_96_24_TimesNetModel:              TimesNet
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            32
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               32
# ...

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('/content/drive/MyDrive/Final_Block/test_embed_ohlcv.csv')

# %%
# !ls
# Out:
# data_btc_1min.pickle	 timesnet_ohlcv_BINANCE_ETHUSDT.P.csv
# fixed_data_btc_1min.csv

# %%
df.head()
# Out:
#                   date      open      high       low     close    volume  \
# 0  2025-02-25 00:00:00  91552.88  91785.19  91470.78  91785.18  44.25582
# 1  2025-02-25 00:33:00  91584.99  91666.67  91444.44  91490.47  26.39075
# 2  2025-02-25 00:35:00  91594.01  91636.67  91477.23  91538.83  87.94442
# 3  2025-02-25 00:38:00  91686.54  91774.45  91585.16  91700.94  71.66851
# 4  2025-02-25 00:45:00  91646.25  91646.25  91463.00  91500.01  81.09762
#
#    pre_return    return
# 0    0.000000 -0.003211
# 1   -0.003211  0.000529
# 2    0.000529  0.001771
# 3    0.001771 -0.002191
# 4   -0.002191  0.001657

# %%
df['pre_return'] = df['close'].pct_change().fillna(0)
# df['return'] = df['pre_return'].shift(-1).fillna(0)

# %%
df['volume'] = df['volume'].astype(float)
df['v_return'] = (df['volume'].shift(-2) - df['volume'].shift(3)).fillna(0)

# %%
df.columns = ['date', 'open', 'high', 'low', 'close','volume','closeTime','quoteAssetVolume', 'numberOfTrades', 'takerBuyBaseVol', 'takerBuyQuoteVol', 'ignore', 'v_return']

# %%
df.columns

df = df[['date', 'volume', 'v_return']].copy()

# %%
df = df.drop('closeTime', axis=1)
df.head()
# Out:
#                  date       open       high        low      close    volume  \
# 0 2025-02-01 00:00:00  102429.56  102431.38  102333.00  102333.01  13.95242
# 1 2025-02-01 00:01:00  102333.01  102360.02  102328.29  102340.67   6.13914
# 2 2025-02-01 00:02:00  102340.67  102363.51  102319.00  102319.01   3.69962
# 3 2025-02-01 00:03:00  102319.01  102330.00  102300.00  102300.01   4.94628
# 4 2025-02-01 00:04:00  102300.00  102319.23  102274.50  102318.00   5.83550
#
#    quoteAssetVolume  numberOfTrades takerBuyBaseVol takerBuyQuoteVol ignore  \
# 0  1428274.95948110            3208      2.41966000  247693.80458960      0
# 1   628315.57433470            1939      3.99198000  408551.32104090      0
# 2   378614.96583750            1778      1.53574000  157173.86438010      0
# 3   506099.53088330            1411      1.89116000  193501.33556970      0
# 4   596938.78673800            3296      4.09921000  419328.96693330      0
#
#    v_return
# 0   0.00000
# 1  -7.81328
# ...

# %%
df.to_csv('/content/drive/MyDrive/TimesNet/Time-Series-Library/dataset/my_data/fixed_data_btc_1min2.csv', index=False)

# %%
# !ls -la ./dataset/my_data/
# !head -5 ./dataset/my_data/test_btc_ohlcv.csv
# Out:
# total 149109
# -rw------- 1 root root 17708520 May 20 11:07 data_btc_1min.pickle
# -rw------- 1 root root 19912892 May 28 06:22 fixed_data_btc_1min1.csv
# -rw------- 1 root root  6176239 May 28 07:11 fixed_data_btc_1min2.csv
# -rw------- 1 root root 21884169 May 28 06:34 fixed_data_btc_1min3.csv
# -rw------- 1 root root 23095731 May 27 14:01 fixed_data_btc_1min.csv
# -rw------- 1 root root   488882 May 28 11:09 test_btc_ohlcv.csv
# -rw------- 1 root root 63419436 May 26 09:12 timesnet_ohlcv_BINANCE_ETHUSDT.P.csv
# date,open,high,low,close,volume,quoteAssetVolume,numberOfTrades,takerBuyBaseVol,takerBuyQuoteVol,ignore,pre_return,return
# 2025-02-25 00:00:00,91552.88,91785.19,91470.78,91785.18,44.25582,4053954.5312275,9784,29.55089,2706580.471996,0,0.0025373314307532,0.0005727504156989
# 2025-02-25 00:45:00,91646.25,91646.25,91463.0,91500.01,81.09762,7423375.6157714,10545,36.73394,3362687.0805975,0,-0.0015955919195376,0.001263824998489
# ...

# %%
#predict next min

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/my_data/ \
  --data_path test_btc_ohlcv.csv\
  --model_id test_btc_ohlcv_timesnet \
  --model TimesNet \
  --data custom \
  --features MS \
  --target 'return' \
  --seq_len 48 \
  --label_len 24 \
  --pred_len 1 \
  --e_layers 1 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 12 \
  --dec_in 12 \
  --c_out 1 \
  --d_model 64 \
  --d_ff 32 \
  --top_k 5 \
  --train_epoch 10 \
  --des 'QuickTest' \
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           test_btc_ohlcv_timesnetModel:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/my_data/
#   Data Path:          test_btc_ohlcv.csv  Features:           MS
#   Target:             return              Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            48                  Label Len:          24
#   Pred Len:           1                   Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             12                  Dec In:             12
#   C Out:              1                   d model:            64
#   n heads:            8                   e layers:           1
# ...

# %%
#predict next min

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/my_data/ \
  --data_path fixed_data_btc_1min2.csv\
  --model_id btc_1min_48_1_TimesNet \
  --model TimesNet \
  --data custom \
  --features MS \
  --target 'v_return' \
  --seq_len 24 \
  --label_len 12 \
  --pred_len 1 \
  --e_layers 1 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 2 \
  --dec_in 2 \
  --c_out 1 \
  --d_model 16 \
  --d_ff 32 \
  --top_k 5 \
  --train_epoch 6 \
  --des 'QuickTest' \
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           btc_1min_48_1_TimesNetModel:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/my_data/
#   Data Path:          fixed_data_btc_1min2.csvFeatures:           MS
#   Target:             v_return            Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            24                  Label Len:          12
#   Pred Len:           1                   Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             2                   Dec In:             2
#   C Out:              1                   d model:            16
#   n heads:            8                   e layers:           1
# ...

# %%
df.head()
# Out:
#                   date      open      high       low     close    volume  \
# 0  2025-02-25 00:00:00  91552.88  91785.19  91470.78  91785.18  44.25582
# 1  2025-02-25 00:33:00  91584.99  91666.67  91444.44  91490.47  26.39075
# 2  2025-02-25 00:35:00  91594.01  91636.67  91477.23  91538.83  87.94442
# 3  2025-02-25 00:38:00  91686.54  91774.45  91585.16  91700.94  71.66851
# 4  2025-02-25 00:45:00  91646.25  91646.25  91463.00  91500.01  81.09762
#
#    pre_return    return
# 0    0.000000 -0.003211
# 1   -0.003211  0.000529
# 2    0.000529  0.001771
# 3    0.001771 -0.002191
# 4   -0.002191  0.001657

# %%
df['future_high'] = df['high'].rolling(window=15).max().shift(-15)
df['future_low'] = df['low'].rolling(window=15).min().shift(-15)

df['range'] = ((df['future_high'] - df['future_low']) / df['close'] * 100).fillna(0)

# %%
def categorize_volatility(range_pct):
    if pd.isna(range_pct):
        return np.nan

    if range_pct >= 0.8:
        return 'high_volatility'
    else:
        return 'normal_volatility'

df['label'] = df['range'].apply(lambda x: categorize_volatility(x))
labels=df['label'].tolist()

from sklearn import preprocessing
import numpy as np

le = preprocessing.LabelEncoder()

labels = le.fit_transform(labels)
print(f"Encoded data: {labels}")

# Get the classes
classes = le.classes_
print(f"Classes: {classes}")
# Out:
# Encoded data: [0 0 0 ... 1 1 1]
# Classes: ['high_volatility' 'normal_volatility']

# %%
len(labels)
# Out:
# 15978

# %%
cnt = 0
for i in labels:
  if i == 0:
    cnt +=1
print(cnt)
# Out:
# 6094

# %%
df['label']=labels
df.head()
# Out:
#                   date      open      high       low     close    volume  \
# 0  2025-02-25 00:00:00  91552.88  91785.19  91470.78  91785.18  44.25582
# 1  2025-02-25 00:33:00  91584.99  91666.67  91444.44  91490.47  26.39075
# 2  2025-02-25 00:35:00  91594.01  91636.67  91477.23  91538.83  87.94442
# 3  2025-02-25 00:38:00  91686.54  91774.45  91585.16  91700.94  71.66851
# 4  2025-02-25 00:45:00  91646.25  91646.25  91463.00  91500.01  81.09762
#
#    pre_return    return  future_high  future_low     range  label
# 0    0.000000 -0.003211      92378.0    91444.44  1.017114      0
# 1   -0.003211  0.000529      92378.0    91463.00  1.000104      0
# 2    0.000529  0.001771      92378.0    91463.00  0.999576      0
# 3    0.001771 -0.002191      92378.0    91463.00  0.997809      0
# 4   -0.002191  0.001657      92378.0    91520.29  0.937388      0

# %%
df.to_csv('/content/drive/MyDrive/Final_Block/classify_ohlcv.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-43062112567f> in <cell line: 0>()
# ----> 1 df.to_csv('/content/drive/MyDrive/Final_Block/embed_ohlcv.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
# !ls -la /content/drive/MyDrive/Final_Block
# !head -5 /content/drive/MyDrive/Final_Block/classify_ohlcv.csv
# Out:
# total 1482778
# -rw------- 1 root root    823270 Jun 10 11:26 best_model.pth
# -rw------- 1 root root   2262777 Jun 10 13:31 classify_ohlcv.csv
# -rw------- 1 root root  39260288 Jun  9 11:32 fused_embeddings_hierarchical.npy
# -rw------- 1 root root  19630208 Jun  9 11:32 fused_embeddings_simple.npy
# -rw------- 1 root root     62978 Jun 10 14:18 Fusion.ipynb
# -rw------- 1 root root  55646415 Jun  8 13:28 news_btc_embeddings.pkl
# -rw------- 1 root root 909344474 May 28 07:42 summ_news.csv
# -rw------- 1 root root    488882 May 28 11:09 test_btc_ohlcv.csv
# -rw------- 1 root root   9815247 Jun  9 08:30 test_news_embeddings.pkl
# -rw------- 1 root root 480937088 Jun  8 13:05 timesnet_backbone_embeddings.npy
# -rw------- 1 root root     89588 Jun  8 13:05 timesnet_labels.npy
# date,open,high,low,close,volume,pre_return,return,future_high,future_low,range,label
# ...

# %%
#classification


# !python -u run.py \
  --task_name classification \
  --is_training 1 \
  --data custom \
  --root_path /content/drive/MyDrive/Final_Block/ \
  --data_path classify_ohlcv.csv \
  --model_id btc_classification_TimesNet \
  --model TimesNet \
  --features MS \
  --target 'label' \
  --seq_len 96 \
  --label_len 48 \
  --pred_len 1 \
  --e_layers 1 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 11 \
  --dec_in 11 \
  --c_out 1 \
  --d_model 768 \
  --d_ff 32 \
  --top_k 5 \
  --train_epoch 1 \
  --des 'QuickTest' \
  --itr 1 \
  --patience 10
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           btc_classification_TimesNetModel:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          /content/drive/MyDrive/Final_Block/
#   Data Path:          classify_ohlcv.csv  Features:           MS
#   Target:             label               Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             11                  Dec In:             11
#   C Out:              1                   d model:            768
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
# ...

# %%
"""
usage: run.py [-h] --task_name TASK_NAME --is_training IS_TRAINING --model_id
              MODEL_ID --model MODEL
              --data DATA [--root_path ROOT_PATH][--data_path DATA_PATH]
              [--features FEATURES] [--target TARGET]
              [--freq FREQ] [--checkpoints CHECKPOINTS]
              [--seq_len SEQ_LEN]
              [--label_len LABEL_LEN] [--pred_len PRED_LEN]
              [--seasonal_patterns SEASONAL_PATTERNS] [--inverse]
              [--mask_rate MASK_RATE]
              [--anomaly_ratio ANOMALY_RATIO]
              [--expand EXPAND] [--d_conv D_CONV] [--top_k TOP_K]
              [--num_kernels NUM_KERNELS] [--enc_in ENC_IN] [--dec_in DEC_IN]
              [--c_out C_OUT] [--d_model D_MODEL] [--n_heads N_HEADS]
              [--e_layers E_LAYERS] [--d_layers D_LAYERS] [--d_ff D_FF]
              [--moving_avg MOVING_AVG] [--factor FACTOR] [--distil]
              [--dropout DROPOUT] [--embed EMBED] [--activation ACTIVATION]
              [--channel_independence CHANNEL_INDEPENDENCE]
              [--decomp_method DECOMP_METHOD] [--use_norm USE_NORM]
              [--down_sampling_layers DOWN_SAMPLING_LAYERS]
              [--down_sampling_window DOWN_SAMPLING_WINDOW]
              [--down_sampling_method DOWN_SAMPLING_METHOD]
              [--seg_len SEG_LEN] [--num_workers NUM_WORKERS] [--itr ITR]
              [--train_epochs TRAIN_EPOCHS] [--batch_size BATCH_SIZE]
              [--patience PATIENCE] [--learning_rate LEARNING_RATE]
              [--des DES] [--loss LOSS] [--lradj LRADJ] [--use_amp]
              [--use_gpu USE_GPU] [--gpu GPU] [--gpu_type GPU_TYPE]
              [--use_multi_gpu] [--devices DEVICES]
              [--p_hidden_dims P_HIDDEN_DIMS [P_HIDDEN_DIMS ...]]
              [--p_hidden_layers P_HIDDEN_LAYERS] [--use_dtw USE_DTW]
              [--augmentation_ratio AUGMENTATION_RATIO] [--seed SEED]
              [--jitter] [--scaling] [--permutation] [--randompermutation]
              [--magwarp] [--timewarp] [--windowslice] [--windowwarp]
              [--rotation] [--spawner] [--dtwwarp] [--shapedtwwarp] [--wdba]
              [--discdtw] [--discsdtw] [--extra_tag EXTRA_TAG]
              [--patch_len PATCH_LEN]
run.py: error: unrecognized arguments: --num_class 2
"""
