# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/TimesNet/
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/TimesNet
# data_preprocess.ipynb	     packet-tracer4.pkt    TimesNet1.ipynb
# news_20250225to20250510.csv  summ_news		   TimesNet.ipynb
# news_preprocess.ipynb	     thuml_timesnet.ipynb
# ohlcv_BINANCE_ETHUSDT.P.csv  Time-Series-Library

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('summ_news.csv')

# %%
df.head()
# Out:
#                          ID           releasedAt  \
# 0  67bf0e677abefca47e66327d  2025-02-25 00:00:00
# 1  67bf0e677abefca47e66327e  2025-02-25 00:00:00
# 2  67bf0e677abefca47e66327f  2025-02-25 00:00:00
# 3  67bf0e677abefca47e663280  2025-02-25 00:00:00
# 4  67bf0e677abefca47e663281  2025-02-25 00:00:00
#
#                                                title  \
# 0  Traders are Elevating Their Portfolio with LIS...
# 1  2025’s Crypto Battle: Altcoin vs. XRP and Bitc...
# 2  Top Cryptos to Buy Now: The Best Choices for 2025
# 3  Explore The Best Crypto Presale to Buy Now wit...
# 4  ITI Launches Master’s in Trading Program for A...
#
#                                             subtitle         sourceName  \
# 0  The digital asset space sees constant shifts, ...     CryptoNewsLand
# 1  Digital currencies now play a key role in glob...  Crypto Front News
# 2  The cryptocurrency market in 2025 offers excit...      TheNewsCrypto
# ...

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
df = pd.read_csv('news_20250225to20250510.csv')
df.head()
# Out:
#                          ID           releasedAt  \
# 0  67bf0e677abefca47e66327d  2025-02-25 00:00:00
# 1  67bf0e677abefca47e66327e  2025-02-25 00:00:00
# 2  67bf0e677abefca47e66327f  2025-02-25 00:00:00
# 3  67bf0e677abefca47e663280  2025-02-25 00:00:00
# 4  67bf0e677abefca47e663281  2025-02-25 00:00:00
#
#                                                title  \
# 0  Traders are Elevating Their Portfolio with LIS...
# 1  2025’s Crypto Battle: Altcoin vs. XRP and Bitc...
# 2  Top Cryptos to Buy Now: The Best Choices for 2025
# 3  Explore The Best Crypto Presale to Buy Now wit...
# 4  ITI Launches Master’s in Trading Program for A...
#
#                                             subtitle         sourceName  \
# 0  The digital asset space sees constant shifts, ...     CryptoNewsLand
# 1  Digital currencies now play a key role in glob...  Crypto Front News
# 2  The cryptocurrency market in 2025 offers excit...      TheNewsCrypto
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241650 entries, 0 to 241649
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             241650 non-null  object
#  1   releasedAt     241650 non-null  object
#  2   title          241650 non-null  object
#  3   subtitle       76905 non-null   object
#  4   sourceName     241650 non-null  object
#  5   sourceUrl      241650 non-null  object
#  6   source         241650 non-null  object
#  7   slug           241649 non-null  object
#  8   asset_names    105848 non-null  object
#  9   asset_slugs    105848 non-null  object
#  10  asset_symbols  199890 non-null  object
#  11  content        241411 non-null  object
# dtypes: object(12)
# memory usage: 22.1+ MB

# %%
for c in df.columns:
  if df[c].isnull().sum() >= 1:
    print(c, df[c].isnull().sum())
# Out:
# subtitle 164745
# slug 1
# asset_names 135802
# asset_slugs 135802
# asset_symbols 41760
# content 239

# %%
for i, r in enumerate(df['content'].isnull()):
  if r:
    print(i)
# Out:
# 323
# 6699
# 8038
# 9731
# 11236
# 11240
# 14851
# 14852
# 15853
# 15959
# 15960
# 15967
# 15968
# 15987
# 15991
# 15993
# 16054
# 16061
# 16069
# 16073
# 16953
# 20167
# 20230
# 25786
# 27783
# 29737
# 29932
# 30155
# 34158
# 34159
# 34160
# 34208
# 34214
# 34226
# 34236
# 34269
# 34288
# 34296
# 34315
# 34321
# 34339
# 34419
# 34420
# 34421
# 34435
# 34502
# 34504
# 34554
# 34584
# 34645
# 34646
# 34651
# 34678
# 34679
# 34683
# 34691
# 36043
# 38649
# 38650
# 38663
# 38710
# 38713
# 38715
# 38727
# 38728
# 38734
# 38753
# 38758
# 38814
# 39134
# 39147
# 40481
# 40610
# 40616
# 40735
# 41248
# 41257
# 41260
# 41261
# 41262
# 41264
# 41266
# 41279
# 41280
# 41290
# 43094
# 43095
# 43096
# 43751
# 43788
# 44081
# 50614
# 52292
# 52307
# 52316
# 52320
# 52321
# 52368
# 52370
# 52379
# 52383
# 52402
# 52403
# 52428
# 52429
# 52443
# 52445
# 52486
# 52490
# 52492
# 54455
# 55232
# 55237
# 55252
# 55276
# 55609
# 57487
# 57491
# 57492
# 57498
# 57502
# 59986
# 59992
# 60532
# 64405
# ...

# %%
df['title'][213123]
# Out:
# 'Binance owes Nigeria $81B'

# %%
df['content'] = df['content'].fillna('').astype(str)

# %%
texts = df['content'].tolist()

# %%
len(texts)
# Out:
# 241650

# %%
c = 0
for i in texts:
  if type(i) == str:
    c += 1

print(c)
# Out:
# 241650

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("tuner007/pegasus_summarizer")
model = AutoModelForSeq2SeqLM.from_pretrained("tuner007/pegasus_summarizer")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
if torch.cuda.is_available():
    model = model.cuda()

# %%
class TextDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx]

def collate_fn(batch):
    return tokenizer(batch, return_tensors="pt", truncation=True,
                    padding="longest", max_length=512)

dataset = TextDataset(texts)
dataloader = DataLoader(dataset, batch_size=32, collate_fn=collate_fn)

summaries = []
model.eval()

with torch.no_grad():
    for batch in dataloader:
        batch = {k: v.to(model.device) for k, v in batch.items()}

        summary_ids = model.generate(
            **batch,
            max_length=60,
            num_beams=5,
            early_stopping=True
        )

        batch_summaries = tokenizer.batch_decode(summary_ids, skip_special_tokens=True)
        summaries.extend(batch_summaries)

df['pegasus_summ'] = summaries

# %%
df.to_csv('summ_news', index=False)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("tuner007/pegasus_summarizer")
model = AutoModelForSeq2SeqLM.from_pretrained("tuner007/pegasus_summarizer")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
summaries = []
for text in texts:
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

df['pegasus_summ'] = summaries
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fed3479b8402> in <cell line: 0>()
#       3     inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)
#       4
# ----> 5     summary_ids = model.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)
#       6
#       7     summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
from transformers import BartForConditionalGeneration, BartTokenizer

mod = BartForConditionalGeneration.from_pretrained("facebook/bart-large", forced_bos_token_id=0)
tok = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
summaries1 = []
for text in texts:
    inputs = tok(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = mod.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tok.decode(summary_ids[0], skip_special_tokens=True)
    summaries1.append(summary)

df['bart_summ'] = summaries1
# Out:
# model:  **facebook/bart-large**
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer_1 = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")
model_1 = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-large-cnn")

# %%
texts = test.tolist()

summaries = []
for text in texts:
    inputs = tokenizer_1(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model_1.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer_1.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

print("model:  **facebook/bart-large-cnn**")
for i, summary in enumerate(summaries):
  print(f"Original [{i+1}]: {texts[i]}")
  print(f"Summary  [{i+1}]: {summary}")
  print("-" * 80)
# Out:
# model:  **facebook/bart-large-cnn**
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer_2 = AutoTokenizer.from_pretrained("philschmid/flan-t5-base-samsum")
model_2 = AutoModelForSeq2SeqLM.from_pretrained("philschmid/flan-t5-base-samsum")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
texts = test.tolist()

summaries = []
for text in texts:
    inputs = tokenizer_2(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model_2.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer_2.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

print("model:  **philschmid/flan-t5-base-samsum**")
for i, summary in enumerate(summaries):
  print(f"Original [{i+1}]: {texts[i]}")
  print(f"Summary  [{i+1}]: {summary}")
  print("-" * 80)
# Out:
# model:  **philschmid/flan-t5-base-samsum**
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer_3 = AutoTokenizer.from_pretrained("facebook/bart-large-xsum")
model_3 = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-large-xsum")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.51k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/309 [00:00<?, ?B/s]

# %%
texts = test.tolist()

summaries = []
for text in texts:
    inputs = tokenizer_3(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model_3.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer_3.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

print("model:  **facebook/bart-large-xsum**")
for i, summary in enumerate(summaries):
  print(f"Original [{i+1}]: {texts[i]}")
  print(f"Summary  [{i+1}]: {summary}")
  print("-" * 80)
# Out:
# model:  **facebook/bart-large-xsum**
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer_4 = AutoTokenizer.from_pretrained("flax-community/t5-base-cnn-dm")
model_4 = AutoModelForSeq2SeqLM.from_pretrained("flax-community/t5-base-cnn-dm")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
texts = test.tolist()

summaries = []
for text in texts:
    inputs = tokenizer_4(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model_4.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer_4.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

print("model:  **flax-community/t5-base-cnn-dm**")
for i, summary in enumerate(summaries):
  print(f"Original [{i+1}]: {texts[i]}")
  print(f"Summary  [{i+1}]: {summary}")
  print("-" * 80)
# Out:
# model:  **flax-community/t5-base-cnn-dm**
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer_5 = AutoTokenizer.from_pretrained("google/pegasus-xsum")
model_5 = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-xsum")
# Out:
# tokenizer_config.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]

# %%
texts = test.tolist()

summaries = []
for text in texts:
    inputs = tokenizer_5(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)

    summary_ids = model_5.generate(**inputs, max_length=60, num_beams=5, early_stopping=True)

    summary = tokenizer_5.decode(summary_ids[0], skip_special_tokens=True)
    summaries.append(summary)

print("model:  **google/pegasus-xsum**")
for i, summary in enumerate(summaries):
  print(f"Original [{i+1}]: {texts[i]}")
  print(f"Summary  [{i+1}]: {summary}")
  print("-" * 80)
# Out:
# model:  **google/pegasus-xsum**
# ...
